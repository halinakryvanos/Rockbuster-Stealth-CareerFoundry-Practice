# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
#create path
path = r'/Users/macbook/Library/CloudStorage/OneDrive-Personal/Data Analisys/Instacart/02 Data'

# %%
#import orders.csv
df_ords = pd.read_csv(os.path.join(path, 'Original Data', '4.3_orders_products', 'orders.csv'), index_col = False)

# %%
#import products.csv
df_prods = pd.read_csv(os.path.join(path, 'Original Data', '4.3_orders_products', 'products.csv'), index_col = False)

# %%
#Dropping the eval_set column from “orders.csv”
df_ords.drop(columns = ['eval_set'])
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
df_ords_2 = df_ords.drop(columns = ['eval_set'])

# %%
df_ords_2.head(15)
# Out:
#     order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1             1          2                  8
# 1    2398795        1             2          3                  7
# 2     473747        1             3          3                 12
# 3    2254736        1             4          4                  7
# 4     431534        1             5          4                 15
# 5    3367565        1             6          2                  7
# 6     550135        1             7          1                  9
# 7    3108588        1             8          1                 14
# 8    2295261        1             9          1                 16
# 9    2550362        1            10          4                  8
# 10   1187899        1            11          4                  8
# 11   2168274        2             1          2                 11
# 12   1501582        2             2          5                 10
# ...

# %%
df_ords_2['days_since_prior_order'].value_counts(dropna = False)
# Out:
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# NaN     206209
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: days_since_prior_order, dtype: int64

# %%
#rename columns
df_ords_2.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
df_ords_2.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_ords_2.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06        3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01        2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01        2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00        1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01        3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# ...

# %%
# Changing Data Type order_id
df_ords_2['order_id'] = df_ords_2['order_id'].astype('str')

# %%
df_ords_2['order_id'].dtype
# Out:
# dtype('O')

# %%
df_ords_2.describe()
# Out:
#             user_id  order_number  orders_day_of_week  order_hour_of_day  \
# count  3.421083e+06  3.421083e+06        3.421083e+06       3.421083e+06
# mean   1.029782e+05  1.715486e+01        2.776219e+00       1.345202e+01
# std    5.953372e+04  1.773316e+01        2.046829e+00       4.226088e+00
# min    1.000000e+00  1.000000e+00        0.000000e+00       0.000000e+00
# 25%    5.139400e+04  5.000000e+00        1.000000e+00       1.000000e+01
# 50%    1.026890e+05  1.100000e+01        3.000000e+00       1.300000e+01
# 75%    1.543850e+05  2.300000e+01        5.000000e+00       1.600000e+01
# max    2.062090e+05  1.000000e+02        6.000000e+00       2.300000e+01
#
#        days_since_prior_order
# count            3.214874e+06
# mean             1.111484e+01
# std              9.206737e+00
# min              0.000000e+00
# 25%              4.000000e+00
# 50%              7.000000e+00
# 75%              1.500000e+01
# max              3.000000e+01

# %%
df_ords_2['order_number'] = df_ords_2['order_number'].astype('str')

# %%
df_ords_2.describe()
# Out:
#             user_id  orders_day_of_week  order_hour_of_day  \
# count  3.421083e+06        3.421083e+06       3.421083e+06
# mean   1.029782e+05        2.776219e+00       1.345202e+01
# std    5.953372e+04        2.046829e+00       4.226088e+00
# min    1.000000e+00        0.000000e+00       0.000000e+00
# 25%    5.139400e+04        1.000000e+00       1.000000e+01
# 50%    1.026890e+05        3.000000e+00       1.300000e+01
# 75%    1.543850e+05        5.000000e+00       1.600000e+01
# max    2.062090e+05        6.000000e+00       2.300000e+01
#
#        days_since_prior_order
# count            3.214874e+06
# mean             1.111484e+01
# std              9.206737e+00
# min              0.000000e+00
# 25%              4.000000e+00
# 50%              7.000000e+00
# 75%              1.500000e+01
# max              3.000000e+01

# %%
df_ords_2['order_id'].dtype
# Out:
# dtype('O')

# %%
df_ords_2['order_number'].dtype
# Out:
# dtype('O')

# %%
#importing departments.csv data set
df_dep = pd.read_csv(os.path.join(path,'Original Data', 'departments.csv'), index_col = False)

# %%
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
#dataframe from the transposed version
df_dep_t = df_dep.T

# %%
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
#index
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# take the first row under tof df_dep_t for the header
new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
# Removing previous header
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
#Adding new header
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_prods.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000

# %%
# Formatting the departments list as an index
data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# i want to know what is it department_id 19
print(data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %%
#Creating a database that contains all department IDs equalling 19 (snacks)
df_snacks = df_prods[df_prods['department_id']==19]

# %%
df_snacks
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %%
df_pets =  df_prods[df_prods['department_id']==8]

# %%
df_pets
# Out:
#        product_id                                    product_name  aisle_id  \
# 20             21                Small & Medium Dental Dog Treats        40
# 25             26     Fancy Feast Trout Feast Flaked Wet Cat Food        41
# 53             54                     24/7 Performance Cat Litter        41
# 91             92          Meat In The Middle Large Rawhide Chews        40
# 235           236                    Chicken Meatballs Dog Treats        40
# ...           ...                                             ...       ...
# 49591       49587  Tender Beef & Liver Feast Classic Wet Cat Food        41
# 49594       49590  Good Budddy, Jerky Strips, Real Chicken Recipe        40
# 49599       49595                            Mixed Grill Dog Food        40
# 49628       49624                  Jumbone® for Small-Medium Dogs        40
# 49691       49687      Smartblend Healthy Metabolism Dry Cat Food        41
#
#        department_id  prices
# ...

# %%
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
# to look for where the value of "department_id" is 19 
df_snacks_2 = df_prods.loc[df_prods['department_id'] == 19]

# %%
df_snacks_2
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %%
df_snacks_3 = df_prods.loc[df_prods['department_id'].isin([19])]

# %%
df_snacks_3
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %%
df_ords_2
# Out:
#         order_id  user_id order_number  orders_day_of_week  order_hour_of_day  \
# 0        2539329        1            1                   2                  8
# 1        2398795        1            2                   3                  7
# 2         473747        1            3                   3                 12
# 3        2254736        1            4                   4                  7
# 4         431534        1            5                   4                 15
# ...          ...      ...          ...                 ...                ...
# 3421078  2266710   206209           10                   5                 18
# 3421079  1854736   206209           11                   4                 10
# 3421080   626363   206209           12                   1                 12
# 3421081  2977660   206209           13                   1                 12
# 3421082   272231   206209           14                   6                 14
#
#          days_since_prior_order
# ...

# %%
#Task 4.4

# %%
df_ords_2.head()
# Out:
#   order_id  user_id order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329        1            1                   2                  8
# 1  2398795        1            2                   3                  7
# 2   473747        1            3                   3                 12
# 3  2254736        1            4                   4                  7
# 4   431534        1            5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Changing the user_id variable to a string
df_ords_2['user_id'] = df_ords_2['user_id'].astype('str')

# %%
df_ords_2['user_id'].dtype
# Out:
# dtype('O')

# %%
# Overwriting the column name for days_since_prior_order to days_since_previous_order
df_ords_2.rename(columns={'user_id' : 'customer_id'}, inplace = True)

# %%
df_ords_2.head()
# Out:
#   order_id customer_id order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329           1            1                   2                  8
# 1  2398795           1            2                   3                  7
# 2   473747           1            3                   3                 12
# 3  2254736           1            4                   4                  7
# 4   431534           1            5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_ords_2['order_hour_of_day'].describe()
# Out:
# count    3.421083e+06
# mean     1.345202e+01
# std      4.226088e+00
# min      0.000000e+00
# 25%      1.000000e+01
# 50%      1.300000e+01
# 75%      1.600000e+01
# max      2.300000e+01
# Name: order_hour_of_day, dtype: float64

# %%
# Converting the variable order_hour_of_day from a float to integer
df_ords_2['order_hour_of_day'] = df_ords_2['order_hour_of_day'].astype('int')

# %%
df_ords_2['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: order_hour_of_day, dtype: int64

# %%
#The busiest hour each day is 10am with a total of 288,418 orders placed followed by 11am at 284,728 orders

# %%
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %%
#In the products.csv dataframe, department_id '4' is listed as produce

# %%
#Creating a subset for breakfast items
df_breakfast = df_prods[df_prods['department_id']==14]

# %%
df_breakfast
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %%
# Creating a subset for dinner items
df_dinner = df_prods[df_prods['department_id'].isin([5, 7, 12, 20])]

# %%
df_dinner.shape
# Out:
# (7650, 5)

# %%
# Our dinner dataframe as 7,650 rows and 5 columns

# %%
# 9 Extracting information about user_id 1
df_ords_user_1 = df_ords_2[df_ords_2['customer_id']=='1']

# %%
df_ords_user_1
# Out:
#    order_id customer_id order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329           1            1                   2                  8
# 1   2398795           1            2                   3                  7
# 2    473747           1            3                   3                 12
# 3   2254736           1            4                   4                  7
# 4    431534           1            5                   4                 15
# 5   3367565           1            6                   2                  7
# 6    550135           1            7                   1                  9
# 7   3108588           1            8                   1                 14
# 8   2295261           1            9                   1                 16
# 9   2550362           1           10                   4                  8
# 10  1187899           1           11                   4                  8
#
#     days_since_prior_order
# 0                      NaN
# ...

# %%
# 10 Details about user_id 1 behaviour
df_ords_user_1.describe()
# Out:
#        orders_day_of_week  order_hour_of_day  days_since_prior_order
# count           11.000000          11.000000               10.000000
# mean             2.636364          10.090909               19.000000
# std              1.286291           3.477198                9.030811
# min              1.000000           7.000000                0.000000
# 25%              1.500000           7.500000               14.250000
# 50%              3.000000           8.000000               19.500000
# 75%              4.000000          13.000000               26.250000
# max              4.000000          16.000000               30.000000

# %%
df_ords_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 6 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                object
#  1   customer_id             object
#  2   order_number            object
#  3   orders_day_of_week      int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 156.6+ MB

# %%
df_dep_t_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21 entries, 1 to 21
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   department  21 non-null     object
# dtypes: object(1)
# memory usage: 892.0+ bytes

# %%
df_ords_2.to_csv(os.path.join(path, 'Prepared Data', 'orders_wrangled.csv'))

# %%
df_dep_t_new.to_csv(os.path.join(path, 'Prepared Data', 'departments_wrangled.csv'))

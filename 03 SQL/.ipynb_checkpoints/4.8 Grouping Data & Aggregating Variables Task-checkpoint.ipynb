# %% [markdown]
# ### This file contains anwers Task 4.8

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# create path
path = r'/Users/macbook/Library/CloudStorage/OneDrive-Personal/Data Analisys/Instacart/02 Data'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, 'Prepared Data', 'orders_products_merged_update.pkl'))

# %%
# Subset DataFrame
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 18)

# %%
df.head(5)
# Out:
#    order_id  customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329            1             1                   2                  8
# 1   2398795            1             2                   3                  7
# 2    473747            1             3                   3                 12
# 3   2254736            1             4                   4                  7
# 4    431534            1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN       196.0                1.0        0.0
# 1                    15.0       196.0                1.0        1.0
# 2                    21.0       196.0                1.0        1.0
# 3                    29.0       196.0                1.0        1.0
# 4                    28.0       196.0                1.0        1.0
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# 0         Soda        77              7     9.0   both  Mid-range product
# 1         Soda        77              7     9.0   both  Mid-range product
# 2         Soda        77              7     9.0   both  Mid-range product
# 3         Soda        77              7     9.0   both  Mid-range product
# 4         Soda        77              7     9.0   both  Mid-range product
#
#       busiest_day        busiest_days busiest_period_of_day
# 0  Regularly busy  Regulary busy days           Most orders
# 1  Regularly busy        Slowest days        Average orders
# 2  Regularly busy        Slowest days           Most orders
# 3      Least busy        Slowest days        Average orders
# 4      Least busy        Slowest days           Most orders

# %% [markdown]
# #### In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# #### Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code

# %%
# Comparing to subset
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %% [markdown]
# Compared to subset, the entire dataframe gives entire picture of order number from all departments. In other words, picture of POPULATION vs. SAMPLE. The range of 'order_number' mean is also larger (DATA SPREAD)

# %% [markdown]
# #### Creating a loyalty flag for existing customers using the transform() and loc() functions

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['customer_id'])['order_number'].transform(np.max)

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  customer_id  order_number  orders_day_of_week  \
# 0    2539329            1             1                   2
# 1    2398795            1             2                   3
# 2     473747            1             3                   3
# 3    2254736            1             4                   4
# 4     431534            1             5                   4
# 5    3367565            1             6                   2
# 6     550135            1             7                   1
# 7    3108588            1             8                   1
# 8    2295261            1             9                   1
# 9    2550362            1            10                   4
# 10   2968173           15            15                   1
# 11   1870022           15            17                   2
# 12   1911383           15            18                   2
# 13   2715276           15            21                   1
# 14    487368           15            22                   1
# 15   2293453           19             2                   5
# 16   1973799           19             5                   6
# 17    532817           19             7                   4
# 18   1573906           21            10                   3
# 19   1593000           31            10                   3
# 20   2231262           31            17                   3
# 21   2580647           43             6                   4
# 22   2187180           43             9                   4
# 23   2497897           52             1                   1
# 24   1318871           52             2                   1
# 25   1261384           52             3                   1
# 26    580568           52             5                   2
# 27   2428073           52             7                   2
# 28    342306           52             9                   1
# 29   1520353           52            10                   2
# 30   2542086           52            11                   2
# 31    944694           52            12                   1
# 32   1268191           52            15                   2
# 33   1122089           52            17                   2
# 34   1498922           52            18                   2
# 35    180919           52            19                   3
# 36   2695875           52            21                   5
# 37   3205960           67             1                   3
# 38    970922           67             2                   1
# 39    596585           67             3                   1
# 40   2037087           67             4                   2
# 41   2474111           67             5                   3
# 42   1568481           67             6                   3
# 43   2048527           67             8                   2
# 44   2389031           67             9                   2
# 45   2378562           67            10                   1
# 46   1515698           67            11                   1
# 47   1928050           67            12                   2
# 48   1949274           67            13                   1
# 49    551869           67            14                   1
# 50    768572           67            16                   4
# 51    150528           67            18                   5
# 52     29758           67            19                   0
# 53   1558976           67            21                   1
# 54    863974           67            22                   1
# 55   2308399           67            23                   1
# 56   2759128           81             3                   1
# 57   1812985           81             5                   2
# 58   1889835           82             1                   3
# 59    499460           82             3                   5
# 60   2728456           82             4                   0
# 61   2653743           82             6                   4
# 62   1358880           82             9                   1
# 63    343588           82            10                   2
# 64   3034663           82            15                   2
# 65    147262           82            18                   1
# 66   3144004           82            19                   2
# 67   2126069           98             3                   0
# 68   2210120           98             7                   5
# 69    681011           98             9                   3
# 70   2846344           98            11                   4
# 71    747431           98            12                   6
# 72   2383054           98            13                   4
# 73   1993729           98            14                   5
# 74   1403849          109             3                   3
# 75    520620          120             1                   3
# 76   3273029          120             3                   2
# 77   1861943          185             2                   1
# 78   2040988          195             1                   1
# 79   1680569          195             8                   1
# 80    276171          195            19                   5
# 81   2744976          195            22                   5
# 82   2781919          195            25                   1
# 83   1738718          195            31                   2
# 84   3058369          195            34                   3
# 85   1485596          195            37                   2
# 86    417035          195            40                   3
# 87   1615297          195            47                   5
# 88   1765587          195            52                   3
# 89    745908          195            57                   4
# 90   2505656          222            17                   2
# 91   3268370          222            38                   5
# 92   2016711          290             9                   5
# 93   2706088          290            28                   6
# 94   1952286          331             6                   5
# 95   3226575          360             1                   5
# 96   1469869          377             3                   5
# 97   1927023          387             2                   4
# 98    858092          420             4                   1
# 99    119314          420             5                   3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN       196.0                1.0
# 1                   7                    15.0       196.0                1.0
# 2                  12                    21.0       196.0                1.0
# 3                   7                    29.0       196.0                1.0
# 4                  15                    28.0       196.0                1.0
# 5                   7                    19.0       196.0                1.0
# 6                   9                    20.0       196.0                1.0
# 7                  14                    14.0       196.0                2.0
# 8                  16                     0.0       196.0                4.0
# 9                   8                    30.0       196.0                1.0
# 10                  9                     7.0       196.0                2.0
# 11                 16                     8.0       196.0                6.0
# 12                 11                     7.0       196.0                1.0
# 13                  9                     7.0       196.0                1.0
# 14                 10                    14.0       196.0                1.0
# 15                 14                     6.0       196.0                3.0
# 16                 12                     8.0       196.0               15.0
# 17                 17                     6.0       196.0                1.0
# 18                 10                     6.0       196.0                2.0
# 19                  8                     7.0       196.0               17.0
# 20                 11                     8.0       196.0               14.0
# 21                 16                     4.0       196.0                9.0
# 22                 12                     3.0       196.0                1.0
# 23                  9                     NaN       196.0                4.0
# 24                 10                     7.0       196.0                5.0
# 25                 10                     7.0       196.0                3.0
# 26                 10                     8.0       196.0                6.0
# 27                  7                     8.0       196.0                5.0
# 28                 11                     7.0       196.0                5.0
# 29                 10                     8.0       196.0                4.0
# 30                  9                     7.0       196.0                3.0
# 31                 16                     6.0       196.0                7.0
# 32                 11                     8.0       196.0                3.0
# 33                 10                     6.0       196.0                4.0
# 34                 10                    14.0       196.0                6.0
# 35                  8                     8.0       196.0                4.0
# 36                 10                    30.0       196.0                1.0
# 37                 11                     NaN       196.0                1.0
# 38                 15                     5.0       196.0                2.0
# 39                 13                     7.0       196.0                2.0
# 40                  9                     8.0       196.0                1.0
# 41                 14                     8.0       196.0                2.0
# 42                 12                     7.0       196.0                2.0
# 43                 11                     7.0       196.0                1.0
# 44                 14                     7.0       196.0                1.0
# 45                 10                     6.0       196.0                1.0
# 46                 11                     7.0       196.0                1.0
# 47                 12                     8.0       196.0                1.0
# 48                 10                     6.0       196.0                1.0
# 49                  9                     7.0       196.0                1.0
# 50                 10                     9.0       196.0                1.0
# 51                 16                     4.0       196.0                1.0
# 52                 14                     9.0       196.0                2.0
# 53                  9                     5.0       196.0                2.0
# 54                 11                    14.0       196.0                3.0
# 55                 14                    14.0       196.0                1.0
# 56                  9                    14.0       196.0                2.0
# 57                 20                    30.0       196.0                1.0
# 58                 15                     NaN       196.0                6.0
# 59                 10                     5.0       196.0                2.0
# 60                 11                    16.0       196.0                1.0
# 61                  9                    13.0       196.0                5.0
# 62                 10                    30.0       196.0                1.0
# 63                 11                     1.0       196.0                1.0
# 64                 11                    12.0       196.0                1.0
# 65                 13                     7.0       196.0                1.0
# 66                 15                     8.0       196.0                1.0
# 67                  9                    25.0       196.0                7.0
# 68                 14                     5.0       196.0                1.0
# 69                  9                    30.0       196.0                1.0
# 70                 13                    15.0       196.0                2.0
# 71                 13                    30.0       196.0                4.0
# 72                 11                    30.0       196.0                1.0
# 73                  8                     8.0       196.0                2.0
# 74                 17                     9.0       196.0                5.0
# 75                 11                     NaN       196.0                2.0
# 76                  8                    19.0       196.0                2.0
# 77                 12                    25.0       196.0               10.0
# 78                 14                     NaN       196.0                2.0
# 79                  9                     4.0       196.0                2.0
# 80                 11                     3.0       196.0                2.0
# 81                 10                     7.0       196.0                2.0
# 82                 14                     4.0       196.0                1.0
# 83                  8                     4.0       196.0                2.0
# 84                 10                     6.0       196.0                2.0
# 85                 15                     0.0       196.0                2.0
# 86                 16                     2.0       196.0                2.0
# 87                 10                     2.0       196.0                2.0
# 88                 12                     2.0       196.0                3.0
# 89                 11                     3.0       196.0                3.0
# 90                 12                     1.0       196.0                2.0
# 91                 15                     1.0       196.0                6.0
# 92                 19                     6.0       196.0                8.0
# 93                 10                     7.0       196.0               16.0
# 94                 16                    30.0       196.0                8.0
# 95                 12                     NaN       196.0                1.0
# 96                 17                     3.0       196.0                9.0
# 97                 10                    22.0       196.0                3.0
# 98                 19                    30.0       196.0                2.0
# 99                 19                    16.0       196.0                2.0
#
#     reordered product_name  aisle_id  department_id  prices _merge  \
# 0         0.0         Soda        77              7     9.0   both
# 1         1.0         Soda        77              7     9.0   both
# 2         1.0         Soda        77              7     9.0   both
# 3         1.0         Soda        77              7     9.0   both
# 4         1.0         Soda        77              7     9.0   both
# 5         1.0         Soda        77              7     9.0   both
# 6         1.0         Soda        77              7     9.0   both
# 7         1.0         Soda        77              7     9.0   both
# 8         1.0         Soda        77              7     9.0   both
# 9         1.0         Soda        77              7     9.0   both
# 10        0.0         Soda        77              7     9.0   both
# 11        1.0         Soda        77              7     9.0   both
# 12        1.0         Soda        77              7     9.0   both
# 13        1.0         Soda        77              7     9.0   both
# 14        1.0         Soda        77              7     9.0   both
# 15        0.0         Soda        77              7     9.0   both
# 16        1.0         Soda        77              7     9.0   both
# 17        1.0         Soda        77              7     9.0   both
# 18        0.0         Soda        77              7     9.0   both
# 19        0.0         Soda        77              7     9.0   both
# 20        1.0         Soda        77              7     9.0   both
# 21        0.0         Soda        77              7     9.0   both
# 22        1.0         Soda        77              7     9.0   both
# 23        0.0         Soda        77              7     9.0   both
# 24        1.0         Soda        77              7     9.0   both
# 25        1.0         Soda        77              7     9.0   both
# 26        1.0         Soda        77              7     9.0   both
# 27        1.0         Soda        77              7     9.0   both
# 28        1.0         Soda        77              7     9.0   both
# 29        1.0         Soda        77              7     9.0   both
# 30        1.0         Soda        77              7     9.0   both
# 31        1.0         Soda        77              7     9.0   both
# 32        1.0         Soda        77              7     9.0   both
# 33        1.0         Soda        77              7     9.0   both
# 34        1.0         Soda        77              7     9.0   both
# 35        1.0         Soda        77              7     9.0   both
# 36        1.0         Soda        77              7     9.0   both
# 37        0.0         Soda        77              7     9.0   both
# 38        1.0         Soda        77              7     9.0   both
# 39        1.0         Soda        77              7     9.0   both
# 40        1.0         Soda        77              7     9.0   both
# 41        1.0         Soda        77              7     9.0   both
# 42        1.0         Soda        77              7     9.0   both
# 43        1.0         Soda        77              7     9.0   both
# 44        1.0         Soda        77              7     9.0   both
# 45        1.0         Soda        77              7     9.0   both
# 46        1.0         Soda        77              7     9.0   both
# 47        1.0         Soda        77              7     9.0   both
# 48        1.0         Soda        77              7     9.0   both
# 49        1.0         Soda        77              7     9.0   both
# 50        1.0         Soda        77              7     9.0   both
# 51        1.0         Soda        77              7     9.0   both
# 52        1.0         Soda        77              7     9.0   both
# 53        1.0         Soda        77              7     9.0   both
# 54        1.0         Soda        77              7     9.0   both
# 55        1.0         Soda        77              7     9.0   both
# 56        0.0         Soda        77              7     9.0   both
# 57        1.0         Soda        77              7     9.0   both
# 58        0.0         Soda        77              7     9.0   both
# 59        1.0         Soda        77              7     9.0   both
# 60        1.0         Soda        77              7     9.0   both
# 61        1.0         Soda        77              7     9.0   both
# 62        1.0         Soda        77              7     9.0   both
# 63        1.0         Soda        77              7     9.0   both
# 64        1.0         Soda        77              7     9.0   both
# 65        1.0         Soda        77              7     9.0   both
# 66        1.0         Soda        77              7     9.0   both
# 67        0.0         Soda        77              7     9.0   both
# 68        1.0         Soda        77              7     9.0   both
# 69        1.0         Soda        77              7     9.0   both
# 70        1.0         Soda        77              7     9.0   both
# 71        1.0         Soda        77              7     9.0   both
# 72        1.0         Soda        77              7     9.0   both
# 73        1.0         Soda        77              7     9.0   both
# 74        0.0         Soda        77              7     9.0   both
# 75        0.0         Soda        77              7     9.0   both
# 76        1.0         Soda        77              7     9.0   both
# 77        0.0         Soda        77              7     9.0   both
# 78        0.0         Soda        77              7     9.0   both
# 79        1.0         Soda        77              7     9.0   both
# 80        1.0         Soda        77              7     9.0   both
# 81        1.0         Soda        77              7     9.0   both
# 82        1.0         Soda        77              7     9.0   both
# 83        1.0         Soda        77              7     9.0   both
# 84        1.0         Soda        77              7     9.0   both
# 85        1.0         Soda        77              7     9.0   both
# 86        1.0         Soda        77              7     9.0   both
# 87        1.0         Soda        77              7     9.0   both
# 88        1.0         Soda        77              7     9.0   both
# 89        1.0         Soda        77              7     9.0   both
# 90        0.0         Soda        77              7     9.0   both
# 91        1.0         Soda        77              7     9.0   both
# 92        0.0         Soda        77              7     9.0   both
# 93        1.0         Soda        77              7     9.0   both
# 94        0.0         Soda        77              7     9.0   both
# 95        0.0         Soda        77              7     9.0   both
# 96        0.0         Soda        77              7     9.0   both
# 97        0.0         Soda        77              7     9.0   both
# 98        0.0         Soda        77              7     9.0   both
# 99        1.0         Soda        77              7     9.0   both
#
#       price_range_loc     busiest_day        busiest_days  \
# 0   Mid-range product  Regularly busy  Regulary busy days
# 1   Mid-range product  Regularly busy        Slowest days
# 2   Mid-range product  Regularly busy        Slowest days
# 3   Mid-range product      Least busy        Slowest days
# 4   Mid-range product      Least busy        Slowest days
# 5   Mid-range product  Regularly busy  Regulary busy days
# 6   Mid-range product  Regularly busy        Busiest days
# 7   Mid-range product  Regularly busy        Busiest days
# 8   Mid-range product  Regularly busy        Busiest days
# 9   Mid-range product      Least busy        Slowest days
# 10  Mid-range product  Regularly busy        Busiest days
# 11  Mid-range product  Regularly busy  Regulary busy days
# 12  Mid-range product  Regularly busy  Regulary busy days
# 13  Mid-range product  Regularly busy        Busiest days
# 14  Mid-range product  Regularly busy        Busiest days
# 15  Mid-range product  Regularly busy  Regulary busy days
# 16  Mid-range product  Regularly busy  Regulary busy days
# 17  Mid-range product      Least busy        Slowest days
# 18  Mid-range product  Regularly busy        Slowest days
# 19  Mid-range product  Regularly busy        Slowest days
# 20  Mid-range product  Regularly busy        Slowest days
# 21  Mid-range product      Least busy        Slowest days
# 22  Mid-range product      Least busy        Slowest days
# 23  Mid-range product  Regularly busy        Busiest days
# 24  Mid-range product  Regularly busy        Busiest days
# 25  Mid-range product  Regularly busy        Busiest days
# 26  Mid-range product  Regularly busy  Regulary busy days
# 27  Mid-range product  Regularly busy  Regulary busy days
# 28  Mid-range product  Regularly busy        Busiest days
# 29  Mid-range product  Regularly busy  Regulary busy days
# 30  Mid-range product  Regularly busy  Regulary busy days
# 31  Mid-range product  Regularly busy        Busiest days
# 32  Mid-range product  Regularly busy  Regulary busy days
# 33  Mid-range product  Regularly busy  Regulary busy days
# 96  Mid-range product  Regularly busy  Regulary busy days
# 97  Mid-range product      Least busy        Slowest days
# 98  Mid-range product  Regularly busy        Busiest days
# 99  Mid-range product  Regularly busy        Slowest days
#
#    busiest_period_of_day  max_order
# 0            Most orders         10
# 1         Average orders         10
# 2            Most orders         10
# 3         Average orders         10
# 4            Most orders         10
# 5         Average orders         10
# 6            Most orders         10
# 7            Most orders         10
# 8            Most orders         10
# 9            Most orders         10
# 10           Most orders         22
# 11           Most orders         22
# 12           Most orders         22
# 13           Most orders         22
# 14           Most orders         22
# 15           Most orders          9
# 16           Most orders          9
# 17           Most orders          9
# 18           Most orders         33
# 19           Most orders         20
# 20           Most orders         20
# 21           Most orders         11
# 22           Most orders         11
# 23           Most orders         27
# 24           Most orders         27
# 25           Most orders         27
# 26           Most orders         27
# 27        Average orders         27
# 28           Most orders         27
# 29           Most orders         27
# 30           Most orders         27
# 31           Most orders         27
# 32           Most orders         27
# 33           Most orders         27
# 34           Most orders         27
# 35           Most orders         27
# 36           Most orders         27
# 37           Most orders         24
# 38           Most orders         24
# 39           Most orders         24
# 40           Most orders         24
# 41           Most orders         24
# 42           Most orders         24
# 43           Most orders         24
# 44           Most orders         24
# 45           Most orders         24
# 46           Most orders         24
# 47           Most orders         24
# 48           Most orders         24
# 49           Most orders         24
# 50           Most orders         24
# 51           Most orders         24
# 52           Most orders         24
# 53           Most orders         24
# 54           Most orders         24
# 55           Most orders         24
# 56           Most orders          7
# 57        Average orders          7
# 58           Most orders         19
# 59           Most orders         19
# 60           Most orders         19
# 61           Most orders         19
# 62           Most orders         19
# 63           Most orders         19
# 64           Most orders         19
# 65           Most orders         19
# 66           Most orders         19
# 67           Most orders         14
# 68           Most orders         14
# 69           Most orders         14
# 70           Most orders         14
# 71           Most orders         14
# 72           Most orders         14
# 73           Most orders         14
# 74           Most orders          6
# 75           Most orders          3
# 76           Most orders          3
# 77           Most orders          6
# 78           Most orders         58
# 79           Most orders         58
# 80           Most orders         58
# 81           Most orders         58
# 82           Most orders         58
# 83           Most orders         58
# 84           Most orders         58
# 85           Most orders         58
# 86           Most orders         58
# 87           Most orders         58
# 88           Most orders         58
# 89           Most orders         58
# 90           Most orders         70
# 91           Most orders         70
# 92           Most orders         51
# 93           Most orders         51
# 94           Most orders          8
# 95           Most orders          3
# 96           Most orders          3
# 97           Most orders          8
# 98           Most orders         22
# 99           Most orders         22

# %% [markdown]
# Creating a flag that assigns a “loyalty” label to a customer_id based on its corresponding max order value

# %% [markdown]
# #### Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge.shape
# Out:
# (32404859, 20)

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  customer_id  order_number  orders_day_of_week  \
# 0    2539329            1             1                   2
# 1    2398795            1             2                   3
# 2     473747            1             3                   3
# 3    2254736            1             4                   4
# 4     431534            1             5                   4
# 5    3367565            1             6                   2
# 6     550135            1             7                   1
# 7    3108588            1             8                   1
# 8    2295261            1             9                   1
# 9    2550362            1            10                   4
# 10   2968173           15            15                   1
# 11   1870022           15            17                   2
# 12   1911383           15            18                   2
# 13   2715276           15            21                   1
# 14    487368           15            22                   1
# 15   2293453           19             2                   5
# 16   1973799           19             5                   6
# 17    532817           19             7                   4
# 18   1573906           21            10                   3
# 19   1593000           31            10                   3
# 20   2231262           31            17                   3
# 21   2580647           43             6                   4
# 22   2187180           43             9                   4
# 23   2497897           52             1                   1
# 24   1318871           52             2                   1
# 25   1261384           52             3                   1
# 26    580568           52             5                   2
# 27   2428073           52             7                   2
# 28    342306           52             9                   1
# 29   1520353           52            10                   2
# 30   2542086           52            11                   2
# 31    944694           52            12                   1
# 32   1268191           52            15                   2
# 33   1122089           52            17                   2
# 34   1498922           52            18                   2
# 35    180919           52            19                   3
# 36   2695875           52            21                   5
# 37   3205960           67             1                   3
# 38    970922           67             2                   1
# 39    596585           67             3                   1
# 40   2037087           67             4                   2
# 41   2474111           67             5                   3
# 42   1568481           67             6                   3
# 43   2048527           67             8                   2
# 44   2389031           67             9                   2
# 45   2378562           67            10                   1
# 46   1515698           67            11                   1
# 47   1928050           67            12                   2
# 48   1949274           67            13                   1
# 49    551869           67            14                   1
# 50    768572           67            16                   4
# 51    150528           67            18                   5
# 52     29758           67            19                   0
# 53   1558976           67            21                   1
# 54    863974           67            22                   1
# 55   2308399           67            23                   1
# 56   2759128           81             3                   1
# 57   1812985           81             5                   2
# 58   1889835           82             1                   3
# 59    499460           82             3                   5
# 60   2728456           82             4                   0
# 61   2653743           82             6                   4
# 62   1358880           82             9                   1
# 63    343588           82            10                   2
# 64   3034663           82            15                   2
# 65    147262           82            18                   1
# 66   3144004           82            19                   2
# 67   2126069           98             3                   0
# 68   2210120           98             7                   5
# 69    681011           98             9                   3
# 70   2846344           98            11                   4
# 71    747431           98            12                   6
# 72   2383054           98            13                   4
# 73   1993729           98            14                   5
# 74   1403849          109             3                   3
# 75    520620          120             1                   3
# 76   3273029          120             3                   2
# 77   1861943          185             2                   1
# 78   2040988          195             1                   1
# 79   1680569          195             8                   1
# 80    276171          195            19                   5
# 81   2744976          195            22                   5
# 82   2781919          195            25                   1
# 83   1738718          195            31                   2
# 84   3058369          195            34                   3
# 85   1485596          195            37                   2
# 86    417035          195            40                   3
# 87   1615297          195            47                   5
# 88   1765587          195            52                   3
# 89    745908          195            57                   4
# 90   2505656          222            17                   2
# 91   3268370          222            38                   5
# 92   2016711          290             9                   5
# 93   2706088          290            28                   6
# 94   1952286          331             6                   5
# 95   3226575          360             1                   5
# 96   1469869          377             3                   5
# 97   1927023          387             2                   4
# 98    858092          420             4                   1
# 99    119314          420             5                   3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     Na
# 84                 10                     6.0       196.0                2.0
# 85                 15                     0.0       196.0                2.0
# 86                 16                     2.0       196.0                2.0
# 87                 10                     2.0       196.0                2.0
# 88                 12                     2.0       196.0                3.0
# 89                 11                     3.0       196.0                3.0
# 90                 12                     1.0       196.0                2.0
# 91                 15                     1.0       196.0                6.0
# 92                 19                     6.0       196.0                8.0
# 93                 10                     7.0       196.0               16.0
# 94                 16                    30.0       196.0                8.0
# 95                 12                     NaN       196.0                1.0
# 96                 17                     3.0       196.0                9.0
# 97                 10                    22.0       196.0                3.0
# 98                 19                    30.0       196.0                2.0
# 99                 19                    16.0       196.0                2.0
#
#     reordered product_name  aisle_id  department_id  prices _merge  \
# 0         0.0         Soda        77              7     9.0   both
# 1         1.0         Soda        77              7     9.0   both
# 2         1.0         Soda        77              7     9.0   both
# 3         1.0         Soda        77              7     9.0   both
# 4         1.0         Soda        77              7     9.0   both
# 5         1.0         Soda        77              7     9.0   both
# 6         1.0         Soda        77              7     9.0   both
# 7         1.0         Soda        77              7     9.0   both
# 8         1.0         Soda        77              7     9.0   both
# 9         1.0         Soda        77              7     9.0   both
# 10        0.0         Soda        77              7     9.0   both
# 11        1.0         Soda        77              7     9.0   both
# 12        1.0         Soda        77              7     9.0   both
# 13        1.0         Soda        77              7     9.0   both
# 14        1.0         Soda        77              7     9.0   both
# 15        0.0         Soda        77              7     9.0   both
# 16        1.0         Soda        77              7     9.0   both
# 17        1.0         Soda        77              7     9.0   both
# 18        0.0         Soda        77              7     9.0   both
# 19        0.0         Soda        77              7     9.0   both
# 20        1.0         Soda        77              7     9.0   both
# 21        0.0         Soda        77              7     9.0   both
# 22        1.0         Soda        77              7     9.0   both
# 23        0.0         Soda        77              7     9.0   both
# 24        1.0         Soda        77              7     9.0   both
# 25        1.0         Soda        77              7     9.0   both
# 26        1.0         Soda        77              7     9.0   both
# 27        1.0         Soda        77              7     9.0   both
# 28        1.0         Soda        77              7     9.0   both
# 29        1.0         Soda        77              7     9.0   both
# 30        1.0         Soda        77              7     9.0   both
# 31        1.0         Soda        77              7     9.0   both
# 32        1.0         Soda        77              7     9.0   both
# 33        1.0         Soda        77              7     9.0   both
# 34        1.0         Soda        77              7     9.0   both
# 35        1.0         Soda        77              7     9.0   both
# 36        1.0         Soda        77              7     9.0   both
# 37        0.0         Soda        77              7     9.0   both
# 38        1.0         Soda        77              7     9.0   both
# 39        1.0         Soda        77              7     9.0   both
# 40        1.0         Soda        77              7     9.0   both
# 41        1.0         Soda        77              7     9.0   both
# 42        1.0         Soda        77              7     9.0   both
# 43        1.0         Soda        77              7     9.0   both
# 44        1.0         Soda        77              7     9.0   both
# 45        1.0         Soda        77              7     9.0   both
# 46        1.0         Soda        77              7     9.0   both
# 47        1.0         Soda        77              7     9.0   both
# 48        1.0         Soda        77              7     9.0   both
# 49        1.0         Soda        77              7     9.0   both
# 50        1.0         Soda        77              7     9.0   both
# 51        1.0         Soda        77              7     9.0   both
# 52        1.0         Soda        77              7     9.0   both
# 53        1.0         Soda        77              7     9.0   both
# 54        1.0         Soda        77              7     9.0   both
# 55        1.0         Soda        77              7     9.0   both
# 56        0.0         Soda        77              7     9.0   both
# 57        1.0         Soda        77              7     9.0   both
# 58        0.0         Soda        77              7     9.0   both
# 59        1.0         Soda        77              7     9.0   both
# 60        1.0         Soda        77              7     9.0   both
# 61        1.0         Soda        77              7     9.0   both
# 62        1.0         Soda        77              7     9.0   both
# 63        1.0         Soda        77              7     9.0   both
# 64        1.0         Soda        77              7     9.0   both
# 65        1.0         Soda        77              7     9.0   both
# 66        1.0         Soda        77              7     9.0   both
# 67        0.0         Soda        77              7     9.0   both
# 68        1.0         Soda        77              7     9.0   both
# 69        1.0         Soda        77              7     9.0   both
# 70        1.0         Soda        77              7     9.0   both
# 71        1.0         Soda        77              7     9.0   both
# 72        1.0         Soda        77              7     9.0   both
# 73        1.0         Soda        77              7     9.0   both
# 74        0.0         Soda        77              7     9.0   both
# 75        0.0         Soda        77              7     9.0   both
# 76        1.0         Soda        77              7     9.0   both
# 77        0.0         Soda        77              7     9.0   both
# 78        0.0         Soda        77              7     9.0   both
# 79        1.0         Soda        77              7     9.0   both
# 80        1.0         Soda        77              7     9.0   both
# 81        1.0         Soda        77              7     9.0   both
# 82        1.0         Soda        77              7     9.0   both
# 83        1.0         Soda        77              7     9.0   both
# 84        1.0         Soda        77              7     9.0   both
# 85        1.0         Soda        77              7     9.0   both
# 86        1.0         Soda        77              7     9.0   both
# 87        1.0         Soda        77              7     9.0   both
# 88        1.0         Soda        77              7     9.0   both
# 89        1.0         Soda        77              7     9.0   both
# 90        0.0         Soda        77              7     9.0   both
# 91        1.0         Soda        77              7     9.0   both
# 92        0.0         Soda        77              7     9.0   both
# 93        1.0         Soda        77              7     9.0   both
# 94        0.0         Soda        77              7     9.0   both
# 95        0.0         Soda        77              7     9.0   both
# 96        0.0         Soda        77              7     9.0   both
# 97        0.0         Soda        77              7     9.0   both
# 98        0.0         Soda        77              7     9.0   both
# 99        1.0         Soda        77              7     9.0   both
#
#       price_range_loc     busiest_day        busiest_days  \
# 0   Mid-range product  Regularly busy  Regulary busy days
# 1   Mid-range product  Regularly busy        Slowest days
# 2   Mid-range product  Regularly busy        Slowest days
# 3   Mid-range product      Least busy        Slowest days
# 4   Mid-range product      Least busy        Slowest days
# 5   Mid-range product  Regularly busy  Regulary busy days
# 6   Mid-range product  Regularly busy        Busiest days
# 7   Mid-range product  Regularly busy        Busiest days
# 8   Mid-range product  Regularly busy        Busiest days
# 9   Mid-range product      Least busy        Slowest days
# 10  Mid-range product  Regularly busy        Busiest days
# 11  Mid-range product  Regularly busy  Regulary busy days
# 12  Mid-range product  Regularly busy  Regulary busy days
# 13  Mid-range product  Regularly busy        Busiest days
# 14  Mid-range product  Regularly busy        Busiest days
# 15  Mid-range product  Regularly busy  Regulary busy days
# 16  Mid-range product  Regularly busy  Regulary busy days
# 17  Mid-range product      Least busy        Slowest days
# 18  Mid-range product  Regularly busy        Slowest days
# 81  Mid-range product  Regularly busy  Regulary busy days
# 82  Mid-range product  Regularly busy        Busiest days
# 83  Mid-range product  Regularly busy  Regulary busy days
# 84  Mid-range product  Regularly busy        Slowest days
# 85  Mid-range product  Regularly busy  Regulary busy days
# 86  Mid-range product  Regularly busy        Slowest days
# 87  Mid-range product  Regularly busy  Regulary busy days
# 88  Mid-range product  Regularly busy        Slowest days
# 89  Mid-range product      Least busy        Slowest days
# 90  Mid-range product  Regularly busy  Regulary busy days
# 91  Mid-range product  Regularly busy  Regulary busy days
# 92  Mid-range product  Regularly busy  Regulary busy days
# 93  Mid-range product  Regularly busy  Regulary busy days
# 94  Mid-range product  Regularly busy  Regulary busy days
# 95  Mid-range product  Regularly busy  Regulary busy days
# 96  Mid-range product  Regularly busy  Regulary busy days
# 97  Mid-range product      Least busy        Slowest days
# 98  Mid-range product  Regularly busy        Busiest days
# 99  Mid-range product  Regularly busy        Slowest days
#
#    busiest_period_of_day  max_order      loyalty_flag
# 0            Most orders         10      New customer
# 1         Average orders         10      New customer
# 2            Most orders         10      New customer
# 3         Average orders         10      New customer
# 4            Most orders         10      New customer
# 5         Average orders         10      New customer
# 6            Most orders         10      New customer
# 7            Most orders         10      New customer
# 8            Most orders         10      New customer
# 9            Most orders         10      New customer
# 10           Most orders         22  Regular customer
# 11           Most orders         22  Regular customer
# 12           Most orders         22  Regular customer
# 13           Most orders         22  Regular customer
# 14           Most orders         22  Regular customer
# 15           Most orders          9      New customer
# 16           Most orders          9      New customer
# 17           Most orders          9      New customer
# 18           Most orders         33  Regular customer
# 19           Most orders         20  Regular customer
# 20           Most orders         20  Regular customer
# 21           Most orders         11  Regular customer
# 22           Most orders         11  Regular customer
# 23           Most orders         27  Regular customer
# 24           Most orders         27  Regular customer
# 25           Most orders         27  Regular customer
# 26           Most orders         27  Regular customer
# 27        Average orders         27  Regular customer
# 28           Most orders         27  Regular customer
# 29           Most orders         27  Regular customer
# 30           Most orders         27  Regular customer
# 31           Most orders         27  Regular customer
# 32           Most orders         27  Regular customer
# 33           Most orders         27  Regular customer
# 34           Most orders         27  Regular customer
# 35           Most orders         27  Regular customer
# 36           Most orders         27  Regular customer
# 37           Most orders         24  Regular customer
# 38           Most orders         24  Regular customer
# 39           Most orders         24  Regular customer
# 40           Most orders         24  Regular customer
# 41           Most orders         24  Regular customer
# 42           Most orders         24  Regular customer
# 43           Most orders         24  Regular customer
# 44           Most orders         24  Regular customer
# 45           Most orders         24  Regular customer
# 46           Most orders         24  Regular customer
# 47           Most orders         24  Regular customer
# 48           Most orders         24  Regular customer
# 49           Most orders         24  Regular customer
# 50           Most orders         24  Regular customer
# 51           Most orders         24  Regular customer
# 52           Most orders         24  Regular customer
# 53           Most orders         24  Regular customer
# 54           Most orders         24  Regular customer
# 55           Most orders         24  Regular customer
# 56           Most orders          7      New customer
# 57        Average orders          7      New customer
# 58           Most orders         19  Regular customer
# 59           Most orders         19  Regular customer
# 60           Most orders         19  Regular customer
# 61           Most orders         19  Regular customer
# 62           Most orders         19  Regular customer
# 63           Most orders         19  Regular customer
# 64           Most orders         19  Regular customer
# 65           Most orders         19  Regular customer
# 66           Most orders         19  Regular customer
# 67           Most orders         14  Regular customer
# 68           Most orders         14  Regular customer
# 69           Most orders         14  Regular customer
# 70           Most orders         14  Regular customer
# 71           Most orders         14  Regular customer
# 72           Most orders         14  Regular customer
# 73           Most orders         14  Regular customer
# 74           Most orders          6      New customer
# 75           Most orders          3      New customer
# 76           Most orders          3      New customer
# 77           Most orders          6      New customer
# 78           Most orders         58    Loyal customer
# 79           Most orders         58    Loyal customer
# 80           Most orders         58    Loyal customer
# 81           Most orders         58    Loyal customer
# 82           Most orders         58    Loyal customer
# 83           Most orders         58    Loyal customer
# 84           Most orders         58    Loyal customer
# 85           Most orders         58    Loyal customer
# 86           Most orders         58    Loyal customer
# 87           Most orders         58    Loyal customer
# 88           Most orders         58    Loyal customer
# 89           Most orders         58    Loyal customer
# 90           Most orders         70    Loyal customer
# 91           Most orders         70    Loyal customer
# 92           Most orders         51    Loyal customer
# 93           Most orders         51    Loyal customer
# 94           Most orders          8      New customer
# 95           Most orders          3      New customer
# 96           Most orders          3      New customer
# 97           Most orders          8      New customer
# 98           Most orders         22  Regular customer
# 99           Most orders         22  Regular customer

# %% [markdown]
# #### The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:
# If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
# Create new column 'avg_price'
ords_prods_merge['avg_price'] = ords_prods_merge.groupby(['customer_id'])['prices'].transform(np.mean)

# %%
# Create a flag that assigns a “types of spenders” label to a user ID based on average prices.
ords_prods_merge.loc[ords_prods_merge['avg_price'] < 10, 'spender_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['avg_price'] >= 10, 'spender_flag'] = 'High spender'

# %%
ords_prods_merge['spender_flag'].value_counts(dropna = False)
# Out:
# Low spender     31770614
# High spender      634245
# Name: spender_flag, dtype: int64

# %% [markdown]
# #### The Instacart team wants to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”

# %%
ords_prods_merge['median_days_since_prior_order'] = ords_prods_merge.groupby(['customer_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order']>20, 'frequency_flag'] = 'Non-frequent customer'
ords_prods_merge.loc[(ords_prods_merge['median_days_since_prior_order']>10) & (ords_prods_merge['median_days_since_prior_order']<=20), 'frequency_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order']<=10, 'frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: frequency_flag, dtype: int64

# %% [markdown]
# #### Export your dataframe as a pickle file and store it correctly in your “Prepared Data” folder.

# %%
# Export to PKL
ords_prods_merge.to_pickle(os.path.join(path,'Prepared Data', 'orders_products_merged_update2.pkl'))

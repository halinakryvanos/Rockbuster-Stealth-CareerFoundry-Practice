# %% [markdown]
# ### This notebook contains the answers to Task 4.9 (Part 1)

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# create path
path = r'/Users/macbook/Library/CloudStorage/OneDrive-Personal/Data Analisys/Instacart'

# %%
# import customers_2.csv
customers = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers_2.csv'))

# %% [markdown]
# #### Complete the fundamental data quality and consistency checks you’ve learned throughout this Achievement; for example, check for and address missing values and duplicates, and convert any mixed-type data

# %%
customers
# Out:
#         user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0         26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1         33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2         65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3        125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4        130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# ...         ...        ...       ...     ...             ...  ...         ...
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
# ...

# %%
customers.shape
# Out:
# (206209, 10)

# %%
# Re-naming columns
customers.rename(columns = {'First Name' : 'first_name', 'Surnam' : 'surnam', 'Gender' : 'gender', 'STATE' : 'state', 'Age' : 'age', 'n_dependants' : 'no_of_dependents','fam_status' : 'marital_status'}, inplace = True)

# %%
customers
# Out:
#         user_id first_name    surnam  gender           state  age date_joined  \
# 0         26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1         33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2         65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3        125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4        130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# ...         ...        ...       ...     ...             ...  ...         ...
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
# ...

# %% [markdown]
# #### Consistency check

# %%
customers.describe()
# Out:
#              user_id            age  no_of_dependents         income
# count  206209.000000  206209.000000     206209.000000  206209.000000
# mean   103105.000000      49.501646          1.499823   94632.852548
# std     59527.555167      18.480962          1.118433   42473.786988
# min         1.000000      18.000000          0.000000   25903.000000
# 25%     51553.000000      33.000000          0.000000   59874.000000
# 50%    103105.000000      49.000000          1.000000   93547.000000
# 75%    154657.000000      66.000000          3.000000  124244.000000
# max    206209.000000      81.000000          3.000000  593901.000000

# %%
# Finding duplicates
customers_dups = customers[customers.duplicated()]

# %%
# Searching for missing values
customers.isnull().sum()
# Out:
# user_id                 0
# first_name          11259
# surnam                  0
# gender                  0
# state                   0
# age                     0
# date_joined             0
# no_of_dependents        0
# marital_status          0
# income                  0
# dtype: int64

# %%
# viewing missing data
df_nan = customers[customers['first_name'].isnull() == True]

# %%
df_nan
# Out:
#         user_id first_name    surnam  gender         state  age date_joined  \
# 53        76659        NaN   Gilbert    Male      Colorado   26    1/1/2017
# 73        13738        NaN     Frost  Female     Louisiana   39    1/1/2017
# 82        89996        NaN    Dawson  Female        Oregon   52    1/1/2017
# 99        96166        NaN   Oconnor    Male      Oklahoma   51    1/1/2017
# 105       29778        NaN    Dawson  Female          Utah   63    1/1/2017
# ...         ...        ...       ...     ...           ...  ...         ...
# 206038   121317        NaN    Melton    Male  Pennsylvania   28   3/31/2020
# 206044   200799        NaN  Copeland  Female        Hawaii   52    4/1/2020
# 206090   167394        NaN     Frost  Female        Hawaii   61    4/1/2020
# 206162   187532        NaN     Floyd  Female    California   39    4/1/2020
# 206171   116898        NaN   Delgado  Female      Colorado   23    4/1/2020
#
#         no_of_dependents marital_status  income
# ...

# %% [markdown]
# 11259 missing values missing for first_name. I don't think this will have much impact on the analysis as we have user_id to identify customers. I will leave the missing values

# %%
# Checking Data types
customers.dtypes
# Out:
# user_id              int64
# first_name          object
# surnam              object
# gender              object
# state               object
# age                  int64
# date_joined         object
# no_of_dependents     int64
# marital_status      object
# income               int64
# dtype: object

# %%
# Check for mixed types
for col in customers.columns.tolist():
  weird = (customers[[col]].applymap(type) != customers[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (customers[weird]) > 0:
    print (col)
# Out:
# first_name

# %% [markdown]
# first_name column returned as having a mixed data type

# %%
# check for the data type of 'first_name'
customers['first_name'].dtype
# Out:
# dtype('O')

# %%
# Convert first_name data type to string
customers['first_name'] = customers['first_name'].astype('str')

# %%
# Check for mixed types
for col in customers.columns.tolist():
  weird = (customers[[col]].applymap(type) != customers[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (customers[weird]) > 0:
    print (col)

# %% [markdown]
# #### Combine your customer data with the rest of your prepared Instacart data. Tip: Make sure the key columns are of the same data type! Hint: Make sure the key columns are the same data type!

# %%
# Import the prepared data
ords_prds_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_update2.pkl'))

# %%
ords_prds_merged.head(5)
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  ...    price_range_loc     busiest_day        busiest_days  \
# ...

# %%
#check the shape
ords_prds_merged.shape
# Out:
# (32404859, 25)

# %% [markdown]
# The common column is user_id. Therefore, we check for the data type of the user_id

# %%
ords_prds_merged['user_id'].dtype
# Out:
# dtype('int64')

# %%
# merge two customers
df_merged = ords_prds_merged.merge(customers, on = 'user_id')

# %%
#check the new df
df_merged.shape
# Out:
# (32404859, 34)

# %%
df_merged['prices'].describe()
# Out:
# count    3.240486e+07
# mean     1.198023e+01
# std      4.956554e+02
# min      1.000000e+00
# 25%      4.200000e+00
# 50%      7.400000e+00
# 75%      1.130000e+01
# max      9.999900e+04
# Name: prices, dtype: float64

# %%
df_merged.loc[df_merged['prices'] > 100]
# Out:
#           order_id  user_id eval_set  order_number  orders_day_of_week  \
# 7805       1435153     1519    prior            26                   2
# 7806       1066435     1519    prior            32                   3
# 15143      1697208     2409    prior            33                   1
# 20264       965345     3531    prior            27                   2
# 20497      2943740     3793    prior             1                   2
# ...            ...      ...      ...           ...                 ...
# 32303799   3265389    51346    prior             4                   1
# 32307882   1179092   131671    prior            12                   4
# 32310810   1226705    39667    prior             7                   2
# 32330048   3000037    95105    prior             2                   4
# 32330049   2741225    95105    prior             4                   5
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %% [markdown]
# From the output 5,127 rows with outlier observations (prices greater than $100).
#
# At the top of the 'prices' column has another odd value, $14,900 which corresponds to the second unexplainable point in the scatterplot. Following this is the 99,999 identified previously.
# It’s the 14,900 and 99,999 values that are skewing charts.
#
# Mark them as missing since they don’t make sense in terms of the other values in the column. To turn them into NaNs

# %%
df_merged.loc[df_merged['prices'] >100, 'prices'] = np.nan

# %%
df_merged['prices'].max()
# Out:
# 25.0

# %% [markdown]
# now the price of grocery items at $25

# %%
df_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  ...         frequency_flag  first_name  surnam  gender    state  \
# ...

# %%
# Export data to pkl
df_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined_4.9_1.pkl'))
